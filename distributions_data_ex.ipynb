# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dist_data = pd.read_csv('Distributions_data_2016.csv')

# %%
dist_data.head()
# Out:
#      company  percentage        demographics   job_category
# 0  anonymous         0.0  Hispanic_or_Latino  Professionals
# 1  anonymous         0.0  Hispanic_or_Latino  Professionals
# 2  anonymous         0.8  Hispanic_or_Latino  Professionals
# 3  anonymous         1.3  Hispanic_or_Latino  Professionals
# 4  anonymous         1.6  Hispanic_or_Latino  Professionals

# %%
dist_data.dtypes
# Out:
# company          object
# percentage      float64
# demographics     object
# job_category     object
# dtype: object

# %%
dist_data.info
# Out:
# <bound method DataFrame.info of          company  percentage                 demographics  \
# 0      anonymous         0.0           Hispanic_or_Latino
# 1      anonymous         0.0           Hispanic_or_Latino
# 2      anonymous         0.8           Hispanic_or_Latino
# 3      anonymous         1.3           Hispanic_or_Latino
# 4      anonymous         1.6           Hispanic_or_Latino
# ...          ...         ...                          ...
# 16037       Uber        42.8  Underrepresented_minorities
# 16038  anonymous        44.4  Underrepresented_minorities
# 16039  anonymous        47.3  Underrepresented_minorities
# 16040  anonymous        48.0  Underrepresented_minorities
# 16041  anonymous        51.6  Underrepresented_minorities
#
#                                             job_category
# 0                                          Professionals
# 1                                          Professionals
# 2                                          Professionals
# ...

# %%
import seaborn as sb

# %%
ax = sb.barplot(data=dist_data, x="demographics", y="percentage")

# %%
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.figure

# %%
ax2 = sb.barplot(data=dist_data, x="job_category", y="percentage")

# %%
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
ax2.figure

# %%
ax3 = sb.barplot(data=dist_data, x="job_category", y="percentage", hue="demographics")

# %%
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=90)
ax3.figure
