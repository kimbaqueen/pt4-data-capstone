# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
train_data = pd.read_csv('train.csv')

# %% [markdown]
# # Exploratory Analysis

# %%
train_data.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won?  avg_training_score  is_promoted
# 0                  8            0                  49            0
# ...

# %%
train_data.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# awards_won?               int64
# avg_training_score        int64
# is_promoted               int64
# dtype: object

# %%
train_data.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'awards_won?', 'avg_training_score',
#        'is_promoted'],
#       dtype='object')

# %%
train_data_subset = train_data[['employee_id', 'department', 'education', 'gender', 'age', 'previous_year_rating','is_promoted']]
train_data_subset
# Out:
#        employee_id         department         education gender  age  \
# 0            65438  Sales & Marketing  Master's & above      f   35
# 1            65141         Operations        Bachelor's      m   30
# 2             7513  Sales & Marketing        Bachelor's      m   34
# 3             2542  Sales & Marketing        Bachelor's      m   39
# 4            48945         Technology        Bachelor's      m   45
# ...            ...                ...               ...    ...  ...
# 54803         3030         Technology        Bachelor's      m   48
# 54804        74592         Operations  Master's & above      f   37
# 54805        13918          Analytics        Bachelor's      m   27
# 54806        13614  Sales & Marketing               NaN      m   29
# 54807        51526                 HR        Bachelor's      m   27
#
#        previous_year_rating  is_promoted
# 0                       5.0            0
# 1                       5.0            0
# ...

# %%
train_data.info
# Out:
# <bound method DataFrame.info of        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
# ...

# %%
train_data_subset.info
# Out:
# <bound method DataFrame.info of        employee_id         department         education gender  age  \
# 0            65438  Sales & Marketing  Master's & above      f   35
# 1            65141         Operations        Bachelor's      m   30
# 2             7513  Sales & Marketing        Bachelor's      m   34
# 3             2542  Sales & Marketing        Bachelor's      m   39
# 4            48945         Technology        Bachelor's      m   45
# ...            ...                ...               ...    ...  ...
# 54803         3030         Technology        Bachelor's      m   48
# 54804        74592         Operations  Master's & above      f   37
# 54805        13918          Analytics        Bachelor's      m   27
# 54806        13614  Sales & Marketing               NaN      m   29
# 54807        51526                 HR        Bachelor's      m   27
#
#        previous_year_rating  is_promoted
# 0                       5.0            0
# ...

# %% [markdown]
# ## Checks for Missing Values & Categorical Value Check

# %%
train_data_subset.isna().sum()
# Out:
# employee_id                0
# department                 0
# education               2409
# gender                     0
# age                        0
# previous_year_rating    4124
# is_promoted                0
# dtype: int64

# %%
train_data_subset['previous_year_rating'].value_counts()
# Out:
# 3.0    18618
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: previous_year_rating, dtype: int64

# %%
train_data_subset['education'].value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
train_data_subset[train_data_subset['education'].isna()]
# Out:
#        employee_id         department education gender  age  \
# 10           29934         Technology       NaN      m   30
# 21           33332         Operations       NaN      m   41
# 32           35465  Sales & Marketing       NaN      f   24
# 43           17423  Sales & Marketing       NaN      m   24
# 82           66013  Sales & Marketing       NaN      m   25
# ...            ...                ...       ...    ...  ...
# 54692        14821  Sales & Marketing       NaN      f   35
# 54717         7684          Analytics       NaN      m   32
# 54729         1797                 HR       NaN      f   28
# 54742        38935  Sales & Marketing       NaN      m   28
# 54806        13614  Sales & Marketing       NaN      m   29
#
#        previous_year_rating  is_promoted
# 10                      NaN            0
# 21                      4.0            0
# 32                      1.0            0
# 43                      2.0            0
# ...

# %%
train_data_subset[train_data_subset['previous_year_rating'].isna()]
# Out:
#        employee_id         department   education gender  age  \
# 10           29934         Technology         NaN      m   30
# 23           71177        Procurement  Bachelor's      m   27
# 29           74759  Sales & Marketing  Bachelor's      m   26
# 56           45709  Sales & Marketing  Bachelor's      f   29
# 58           26599  Sales & Marketing  Bachelor's      m   27
# ...            ...                ...         ...    ...  ...
# 54703        74615                R&D  Bachelor's      m   30
# 54734        11685         Operations  Bachelor's      m   31
# 54746        10546            Finance  Bachelor's      m   28
# 54773        37919            Finance  Bachelor's      m   23
# 54801        12431         Technology  Bachelor's      f   31
#
#        previous_year_rating  is_promoted
# 10                      NaN            0
# 23                      NaN            0
# 29                      NaN            0
# 56                      NaN            0
# ...

# %% [markdown]
# ## Basic Statistics

# %%
train_data_subset.describe()
# Out:
#         employee_id           age  previous_year_rating   is_promoted
# count  54808.000000  54808.000000          50684.000000  54808.000000
# mean   39195.830627     34.803915              3.329256      0.085170
# std    22586.581449      7.660169              1.259993      0.279137
# min        1.000000     20.000000              1.000000      0.000000
# 25%    19669.750000     29.000000              3.000000      0.000000
# 50%    39225.500000     33.000000              3.000000      0.000000
# 75%    58730.500000     39.000000              4.000000      0.000000
# max    78298.000000     60.000000              5.000000      1.000000

# %% [markdown]
# ## Visualizations of Major Variables

# %%
train_data_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot: title={'center': 'employee_id'}>,
#         <AxesSubplot: title={'center': 'age'}>],
#        [<AxesSubplot: title={'center': 'previous_year_rating'}>,
#         <AxesSubplot: title={'center': 'is_promoted'}>]], dtype=object)

# %%
train_data_subset[['employee_id', 'age']].plot(kind='scatter', x='employee_id', y='age', figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='employee_id', ylabel='age'>

# %% [markdown]
# # Data Wrangling / Cleansing

# %%
# mask = ((train_data_subset['column-name']=='value-name') | (train_data_subset['column-name']=='value-name'))

# %%
train_data_subset.fillna('Not Applicable')
# Out:
#        employee_id         department         education gender  age  \
# 0            65438  Sales & Marketing  Master's & above      f   35
# 1            65141         Operations        Bachelor's      m   30
# 2             7513  Sales & Marketing        Bachelor's      m   34
# 3             2542  Sales & Marketing        Bachelor's      m   39
# 4            48945         Technology        Bachelor's      m   45
# ...            ...                ...               ...    ...  ...
# 54803         3030         Technology        Bachelor's      m   48
# 54804        74592         Operations  Master's & above      f   37
# 54805        13918          Analytics        Bachelor's      m   27
# 54806        13614  Sales & Marketing    Not Applicable      m   29
# 54807        51526                 HR        Bachelor's      m   27
#
#       previous_year_rating  is_promoted
# 0                      5.0            0
# 1                      5.0            0
# ...

# %%
train_data_subset.isna().sum()
# Out:
# employee_id                0
# department                 0
# education               2409
# gender                     0
# age                        0
# previous_year_rating    4124
# is_promoted                0
# dtype: int64

# %%
train_data_subset[train_data_subset['education'].isna()]
# Out:
#        employee_id         department education gender  age  \
# 10           29934         Technology       NaN      m   30
# 21           33332         Operations       NaN      m   41
# 32           35465  Sales & Marketing       NaN      f   24
# 43           17423  Sales & Marketing       NaN      m   24
# 82           66013  Sales & Marketing       NaN      m   25
# ...            ...                ...       ...    ...  ...
# 54692        14821  Sales & Marketing       NaN      f   35
# 54717         7684          Analytics       NaN      m   32
# 54729         1797                 HR       NaN      f   28
# 54742        38935  Sales & Marketing       NaN      m   28
# 54806        13614  Sales & Marketing       NaN      m   29
#
#        previous_year_rating  is_promoted
# 10                      NaN            0
# 21                      4.0            0
# 32                      1.0            0
# 43                      2.0            0
# ...

# %%
train_data_subset['education'].fillna('Not Provided', inplace=True)
train_data_subset['previous_year_rating'].fillna(3.0, inplace=True)
# Out:
# /var/folders/gl/wdltsr_94r503kcx0k1zhv5r0000gp/T/ipykernel_42347/4182700837.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/gl/wdltsr_94r503kcx0k1zhv5r0000gp/T/ipykernel_42347/4182700837.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_data_subset.isna().sum()
# Out:
# employee_id             0
# department              0
# education               0
# gender                  0
# age                     0
# previous_year_rating    0
# is_promoted             0
# dtype: int64

# %% [markdown]
# ## Success in updating all NaN!

# %% [markdown]
# # Analyzing relationships data

# %%
train_data_subset['is_promoted'].value_counts(normalize=True)
# Out:
# 0    0.91483
# 1    0.08517
# Name: is_promoted, dtype: float64

# %%
train_data_subset['is_promoted'].mean()
# Out:
# 0.08517004816815063

# %%
train_data_subset.groupby('gender').is_promoted.mean()
# Out:
# gender
# f    0.089934
# m    0.083151
# Name: is_promoted, dtype: float64

# %%
train_data_subset.groupby(['gender', 'department', 'education']).is_promoted.mean()
# Out:
# gender  department         education
# f       Analytics          Bachelor's          0.126667
#                            Master's & above    0.075000
#                            Not Provided        0.086957
#         Finance            Bachelor's          0.083172
#                            Below Secondary     0.031250
#                                                  ...
# m       Sales & Marketing  Not Provided        0.051042
#         Technology         Bachelor's          0.108262
#                            Below Secondary     0.171875
#                            Master's & above    0.117604
#                            Not Provided        0.096774
# Name: is_promoted, Length: 64, dtype: float64

# %%
train_data_subset['department'].value_counts()
# Out:
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: department, dtype: int64

# %%
grouped_df = train_data_subset.groupby(['gender', 'department', 'education']).is_promoted.mean()
grouped_df
# Out:
# gender  department         education
# f       Analytics          Bachelor's          0.126667
#                            Master's & above    0.075000
#                            Not Provided        0.086957
#         Finance            Bachelor's          0.083172
#                            Below Secondary     0.031250
#                                                  ...
# m       Sales & Marketing  Not Provided        0.051042
#         Technology         Bachelor's          0.108262
#                            Below Secondary     0.171875
#                            Master's & above    0.117604
#                            Not Provided        0.096774
# Name: is_promoted, Length: 64, dtype: float64

# %%
grouped_df.describe()
# Out:
# count    64.000000
# mean      0.070023
# std       0.039347
# min       0.000000
# 25%       0.045455
# 50%       0.071429
# 75%       0.088666
# max       0.181818
# Name: is_promoted, dtype: float64

# %%
train_data_subset[train_data_subset.is_promoted == 1].gender.value_counts()
# Out:
# m    3201
# f    1467
# Name: gender, dtype: int64

# %%
train_data_subset[train_data_subset.is_promoted == 1].gender.value_counts(normalize=True)
# Out:
# m    0.685733
# f    0.314267
# Name: gender, dtype: float64

# %%
train_data_subset[train_data_subset.gender == 'm'].department.value_counts(normalize=True)
# Out:
# Sales & Marketing    0.355517
# Operations           0.173291
# Analytics            0.125701
# Technology           0.112999
# Procurement          0.100036
# Finance              0.048187
# HR                   0.036679
# R&D                  0.024470
# Legal                0.023119
# Name: department, dtype: float64

# %%
train_data_subset[train_data_subset.gender == 'f'].department.value_counts(normalize=True)
# Out:
# Operations           0.286721
# Procurement          0.201508
# Sales & Marketing    0.193355
# Technology           0.170917
# HR                   0.061672
# Finance              0.041748
# Analytics            0.031449
# Legal                0.009134
# R&D                  0.003494
# Name: department, dtype: float64

# %%
df_groupedby_gender_dept = train_data_subset.groupby('department').gender.value_counts(normalize=True)
df_groupedby_gender_dept
# Out:
# department         gender
# Analytics          m         0.904148
#                    f         0.095852
# Finance            m         0.731467
#                    f         0.268533
# HR                 m         0.583954
#                    f         0.416046
# Legal              m         0.856593
#                    f         0.143407
# Operations         m         0.587857
#                    f         0.412143
# Procurement        m         0.539507
#                    f         0.460493
# R&D                m         0.942943
#                    f         0.057057
# Sales & Marketing  m         0.812708
#                    f         0.187292
# Technology         m         0.609414
#                    f         0.390586
# Name: gender, dtype: float64

# %%
dfg = train_data_subset.groupby('department').gender.value_counts(normalize=True).unstack()

dfgx = dfg.plot(kind='bar', figsize=(12,5), xlabel='Department', ylabel='Count', rot=0)
dfgx.legend(bbox_to_anchor=(1.02, 1), loc='upper left', title='Gender')
plt.title('Employees by Department', size=24)
plt.savefig('trainemployeesbydept.png');

# %% [markdown]
# # Statistical Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
p = sns.PairGrid(train_data_subset)
p.map(sns.scatterplot);

# %%
sns.histplot(x='department', data=train_data_subset, hue='gender', multiple='dodge', shrink=0.8, palette='plasma');
sns.set( rc = {'figure.figsize' : (20,20), 'axes.labelsize' : 10})
sns.set_style('white')

# %%
g = sns.FacetGrid(train_data_subset, col='education', hue='gender', palette='plasma', height=5, aspect=2.5);
g.map(sns.histplot, 'department')
g.set_titles(col_template='{col_name} Education');

# %%
sns.displot(x='department', data=train_data_subset, hue='gender', palette="plasma", aspect=2.2, shrink=0.8);

# %%
t = sns.barplot(data=train_data, x="department", y="is_promoted", hue="gender")
t.set_xticklabels(t.get_xticklabels(), rotation=90)
t.figure

# %%
# df_groupedby_gender_dept

# dfgx = dfg.plot(kind='bar', figsize=(12,5), xlabel='Department', ylabel='Count', rot=0)
# dfgx.legend(bbox_to_anchor=(1.02, 1), loc='upper left', title='Gender')
# plt.title('Employees by Department', size=24)
