# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
tech_diversity_data = pd.read_csv('Tech_sector_diversity_demographics_2016.csv')

# %%
tech_diversity_data.head()
# Out:
#   job_category             race_ethnicity  gender   count  percentage
# 0  All workers                      White    Male  268883   41.257252
# 1  All workers                      White  Female  105560   16.197065
# 2  All workers  Black_or_African American    Male   17508    2.686417
# 3  All workers  Black_or_African American  Female   11479    1.761331
# 4  All workers                      Asian    Male  125347   19.233171

# %%
tech_diversity_data.dtypes
# Out:
# job_category       object
# race_ethnicity     object
# gender             object
# count               int64
# percentage        float64
# dtype: object

# %%
tech_diversity_data.info
# Out:
# <bound method DataFrame.info of      job_category             race_ethnicity  gender   count  percentage
# 0     All workers                      White    Male  268883   41.257252
# 1     All workers                      White  Female  105560   16.197065
# 2     All workers  Black_or_African American    Male   17508    2.686417
# 3     All workers  Black_or_African American  Female   11479    1.761331
# 4     All workers                      Asian    Male  125347   19.233171
# 5     All workers                      Asian  Female   58049    8.907005
# 6     All workers         Hispanic_or_Latino    Male   32201    4.940903
# 7     All workers         Hispanic_or_Latino  Female   15512    2.380152
# 8      Executives                      White    Male    7282   58.678485
# 9      Executives                      White  Female    1818   14.649476
# 10     Executives  Black_or_African American    Male     120    0.966962
# ...

# %%
import seaborn as sb

# %%
tdx = sb.barplot(data=tech_diversity_data, x="race_ethnicity", y="percentage", hue="gender")

# %%
tdx2 = sb.barplot(data=tech_diversity_data, x="job_category", y="percentage", hue="gender")

# %%
tdx3 = sb.barplot(data=tech_diversity_data, x="job_category", y="percentage", hue="race_ethnicity")

# %%
tdx4 = sb.barplot(data=tech_diversity_data, x="gender", y="percentage", hue="race_ethnicity")
